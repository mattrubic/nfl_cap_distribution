# %% [markdown]
# Goal here is to build a basic model, reiterate later upon study of other solutions, revisit with different valuation method

# %% [markdown]
# **Rough draft to be edited for clarity**
#
# In NFL, what is the best way to distribute value across cap?
#
# Clustering (assumptions): minimum / rookie contract / free agent / franchise tag / outliers
#
# 53+ roster spots.
#
# How many of each contract can be afforded, and what is the optimal distribution?
#
# Then account for positional value?

# %% [markdown]
# cluster by salary, Measure AV/salary for all and determine optimal distribution of salaries by contract type by AV (as a basic measure of player value)

# %% [markdown]
# **Import the data**
#
# need to use webscraping.
#
# Use pfr and spotrac as the sources. in future I think I would use these files to make a sql database
#
# Not sure which value to use for spotrac, average only appears available for active (2022-) contracts, historical values seem
# subject to be skewed by  things like contract restructures -- sorting by 'cash' seems to provide desired values, though this may be misleading for players whose salary is being paid by former team -- might make sense to go player by player and use yearly totals from 'career earnings', which appears to be cash values paid across all teams for a season
#
# spotrac and pfr seem to be consistent with which players were on which rosters historically, though spotrac adds has players across categories like injury IR, dead cap, practice squad etc. and classifies based on which category a player is in at the end of the season.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get('https://www.pro-football-reference.com/teams/buf/2021_roster.htm')
soup = BeautifulSoup(driver.page_source,'lxml')
driver.quit()
table = soup.find_all('table')[0]  #This is the index of any table of that page. If you change it you can get different tables.
tab_data = [[celldata.text for celldata in rowdata.find_all(["th","td"])]
                        for rowdata in table.find_all("tr")]
for data in tab_data[1:-1]: #first and last rows are names of the columns and team totals respectively
    print(' '.join(data))
    

#create dictionary of all team names as they appear on pfr and get all tables, keep each table separate
# Out:
# 97 Mario Addison 34 DE 17 0 260 6-3 Troy 9/6/1987 10 2
# 17 Josh Allen 25 QB 17 17 237 6-5 Wyoming 5/21/1996 3 19 Buffalo Bills / 1st / 7th pick / 2018
# 51 Eli Ankou 27 DT 5 0 325 6-3 UCLA 6/8/1994 4 1
# 96 Boogie Basham 24 DL 8 0 281 6-3 Wake Forest 12/16/1997 Rook 1 Buffalo Bills / 2nd / 61st pick / 2021
# 2 Tyler Bass 24 K 17 0 183 5-10 Georgia Southern 2/14/1997 1 3 Buffalo Bills / 6th / 188th pick / 2020
# 71 Ryan Bates 24 OL 17 4 302 6-4 Penn St. 2/14/1997 2 3
# 11 Cole Beasley 32 WR 16 8 174 5-8 SMU 4/26/1989 9 7
# 65 Ike Boettger 27 G 15 10 313 6-6 Iowa 10/5/1994 3 5
# 22 Matt Breida 26 RB 9 0 195 5-10 Georgia Southern 2/28/1995 4 2
# 79 Spencer Brown 23 OT 13 10 311 6-9 Northern Iowa 2/28/1998 Rook 6 Buffalo Bills / 3rd / 93rd pick / 2021
# 90 Brandin Bryant 28 DL 2 0 294 6-3 Florida Atlantic 9/16/1993 2 0
# 94 Vernon Butler 27 DT 10 1 330 6-4 Louisiana Tech 6/14/1994 5 1 Carolina Panthers / 1st / 30th pick / 2016
# 13 Gabriel Davis 22 WR 16 4 210 6-2 Central Florida 4/1/1999 1 5 Buffalo Bills / 4th / 128th pick / 2020
# 73 Dion Dawkins 27 OG 16 15 320 6-5 Temple 4/26/1994 4 12 Buffalo Bills / 2nd / 63rd pick / 2017
# 61 Justin Zimmer 29 DT 6 0 300 6-3 Ferris St. 10/23/1992 3 1

# %%
tab_data #list of lists, each list is all player info as strings
# Out:
# [['No.',
#   'Player',
#   'Age',
#   'Pos',
#   'G',
#   'GS',
#   'Wt',
#   'Ht',
#   'College/Univ',
#   'BirthDate',
#   'Yrs',
#   'AV',
#   'Drafted (tm/rnd/yr)'],
#  ['97',
#   'Mario Addison',
#   '34',
#   'DE',
#   '17',
#   '0',
#   '260',
#   '6-3',
#   'Troy',
#   '9/6/1987',
#   '10',
#   '2',
#   ''],
#  ['17',
#   'Josh Allen',
#   '25',
#   'QB',
#   '17',
#   '17',
#   '237',
#   '6-5',
#   'Wyoming',
#   '5/21/1996',
#   '3',
#   '19',
#   'Buffalo Bills / 1st / 7th pick / 2018'],
#  ['51',
#   'Eli Ankou',
#   '27',
#   'DT',
#   '5',
#   '0',
#   '325',
#   '6-3',
#   'UCLA',
#   '6/8/1994',
#   '4',
#   '1',
#   ''],
#  ['96',
#   'Boogie Basham',
#   '24',
#   'DL',
#   '8',
#   '0',
#   '281',
#   '6-3',
#   'Wake Forest',
#   '12/16/1997',
#   'Rook',
#   '1',
#   'Buffalo Bills / 2nd / 61st pick / 2021'],
#  ['2',
#   'Tyler Bass',
#   '24',
#   'K',
#   '17',
#   '0',
#   '183',
#   '5-10',
#   'Georgia Southern',
#   '2/14/1997',
#   '1',
#   '3',
#   'Buffalo Bills / 6th / 188th pick / 2020'],
#  ['71',
#   'Ryan Bates',
#   '24',
#   'OL',
#   '17',
#   '4',
#   '302',
#   '6-4',
#   'Penn St.',
#   '2/14/1997',
#   '2',
#   '3',
#   ''],
#  ['11',
#   'Cole Beasley',
#   '32',
#   'WR',
#   '16',
#   '8',
#   '174',
#   '5-8',
#   'SMU',
#   '4/26/1989',
#   '9',
#   '7',
#   ''],
#  ['65',
#   'Ike Boettger',
#   '27',
#   'G',
#   '15',
#   '10',
#   '313',
#   '6-6',
#   'Iowa',
#   '10/5/1994',
#   '3',
#   '5',
#   ''],
#  ['22',
#   'Matt Breida',
#   '26',
#   'RB',
#   '9',
#   '0',
#   '195',
#   '5-10',
#   'Georgia Southern',
#   '2/28/1995',
#   '4',
#   '2',
#   ''],
#  ['79',
#   'Spencer Brown',
#   '23',
#   'OT',
#   '13',
#   '10',
#   '311',
#   '6-9',
#   'Northern Iowa',
#   '2/28/1998',
#   'Rook',
#   '6',
#   'Buffalo Bills / 3rd / 93rd pick / 2021'],
#  ['90',
#   'Brandin Bryant',
#   '28',
#   'DL',
#   '2',
#   '0',
#   '294',
#   '6-3',
#   'Florida Atlantic',
#   '9/16/1993',
#   '2',
#   '0',
#   ''],
#  ['94',
#   'Vernon Butler',
#   '27',
#   'DT',
#   '10',
#   '1',
#   '330',
#   '6-4',
#   'Louisiana Tech',
#   '6/14/1994',
#   '5',
#   '1',
#   'Carolina Panthers / 1st / 30th pick / 2016'],
#  ['13',
#   'Gabriel Davis',
#   '22',
#   'WR',
#   '16',
#   '4',
#   '210',
#   '6-2',
#   'Central Florida',
#   '4/1/1999',
#   '1',
#   '5',
#   'Buffalo Bills / 4th / 128th pick / 2020'],
#  ['73',
#   'Dion Dawkins',
#   '27',
#   'OG',
#   '16',
#   '15',
#   '320',
#   '6-5',
#   'Temple',
#   '4/26/1994',
#   '4',
#   '12',
#   'Buffalo Bills / 2nd / 63rd pick / 2017'],
#  ['14',
#   'Stefon Diggs',
#   '28',
#   'WR',
#   '17',
#   '17',
#   '191',
#   '6-0',
#   'Maryland',
#   '11/29/1993',
#   '6',
#   '12',
#   'Minnesota Vikings / 5th / 146th pick / 2015'],
#  ['53',
#   'Tyrel Dodson',
#   '23',
#   'LB',
#   '16',
#   '0',
#   '237',
#   '6-0',
#   'Texas A&M',
#   '6/25/1998',
#   '1',
#   '2',
#   ''],
#  ['77',
#   'Jamil Douglas',
#   '29',
#   'OG',
#   '1',
#   '0',
#   '309',
#   '6-4',
#   'Arizona St.',
#   '2/28/1992',
#   '6',
#   '0',
#   'Miami Dolphins / 4th / 114th pick / 2015'],
#  ['72',
#   'Tommy Doyle',
#   '23',
#   'OL',
#   '11',
#   '0',
#   '320',
#   '6-8',
#   'Miami (OH)',
#   '5/6/1998',
#   'Rook',
#   '1',
#   'Buffalo Bills / 5th / 161st pick / 2021'],
#  ['49',
#   'Tremaine Edmunds',
#   '23',
#   'ILB',
#   '15',
#   '15',
#   '250',
#   '6-5',
#   'Virginia Tech',
#   '5/2/1998',
#   '3',
#   '9',
#   'Buffalo Bills / 1st / 16th pick / 2018'],
#  ['57',
#   'A.J. Epenesa',
#   '23',
#   'DL',
#   '14',
#   '0',
#   '260',
#   '6-6',
#   'Iowa',
#   '9/15/1998',
#   '1',
#   '1',
#   'Buffalo Bills / 2nd / 54th pick / 2020'],
#  ['76',
#   'Jon Feliciano',
#   '29',
#   'OG',
#   '9',
#   '6',
#   '325',
#   '6-4',
#   'Miami (FL)',
#   '2/10/1992',
#   '6',
#   '3',
#   'Oakland Raiders / 4th / 128th pick / 2015'],
#  ['69',
#   'Reid Ferguson',
#   '27',
#   'LS',
#   '17',
#   '0',
#   '235',
#   '6-2',
#   'LSU',
#   '3/24/1994',
#   '4',
#   '1',
#   ''],
#  ['74',
#   'Cody Ford',
#   '25',
#   'OL',
#   '15',
#   '7',
#   '329',
#   '6-3',
#   'Oklahoma',
#   '12/28/1996',
#   '2',
#   '4',
#   'Buffalo Bills / 2nd / 38th pick / 2019'],
#  ['42',
#   'Joe Giles-Harris',
#   '24',
#   'LB',
#   '2',
#   '0',
#   '234',
#   '6-2',
#   'Duke',
#   '4/1/1997',
#   '2',
#   '0',
#   ''],
#  ['41',
#   'Reggie Gilliam',
#   '24',
#   'TE',
#   '16',
#   '5',
#   '244',
#   '6-0',
#   'Toledo',
#   '8/20/1997',
#   '1',
#   '0',
#   ''],
#  ['3',
#   'Matt Haack',
#   '27',
#   'P',
#   '17',
#   '0',
#   '205',
#   '6-0',
#   'Arizona St.',
#   '7/25/1994',
#   '4',
#   '1',
#   ''],
#  ['31',
#   'Damar Hamlin',
#   '23',
#   'S',
#   '14',
#   '0',
#   '200',
#   '6-0',
#   'Pittsburgh',
#   '3/24/1998',
#   'Rook',
#   '1',
#   'Buffalo Bills / 6th / 212th pick / 2021'],
#  ['68',
#   'Bobby Hart',
#   '27',
#   'OG',
#   '1',
#   '0',
#   '310',
#   '6-5',
#   'Florida St.',
#   '8/21/1994',
#   '6',
#   '0',
#   'New York Giants / 7th / 226th pick / 2015'],
#  ['16',
#   'Isaiah Hodgins',
#   '23',
#   'WR',
#   '1',
#   '0',
#   '210',
#   '6-4',
#   'Oregon St.',
#   '10/21/1998',
#   'Rook',
#   '0',
#   'Buffalo Bills / 6th / 207th pick / 2020'],
#  ['55',
#   'Jerry Hughes',
#   '33',
#   'DE',
#   '17',
#   '16',
#   '254',
#   '6-2',
#   'TCU',
#   '8/13/1988',
#   '11',
#   '9',
#   'Indianapolis Colts / 1st / 31st pick / 2010'],
#  ['23',
#   'Micah Hyde',
#   '31',
#   'S',
#   '17',
#   '17',
#   '197',
#   '6-0',
#   'Iowa',
#   '12/31/1990',
#   '8',
#   '12',
#   'Green Bay Packers / 5th / 159th pick / 2013'],
#  ['30',
#   'Dane Jackson',
#   '25',
#   'CB',
#   '17',
#   '6',
#   '180',
#   '5-11',
#   'Pittsburgh',
#   '11/29/1996',
#   '1',
#   '3',
#   'Buffalo Bills / 7th / 239th pick / 2020'],
#  ['46',
#   'Jaquan Johnson',
#   '26',
#   'CB',
#   '17',
#   '1',
#   '191',
#   '5-10',
#   'Miami (FL)',
#   '11/6/1995',
#   '2',
#   '1',
#   'Buffalo Bills / 6th / 181st pick / 2019'],
#  ['24',
#   'Taron Johnson',
#   '25',
#   'CB',
#   '16',
#   '15',
#   '192',
#   '5-11',
#   'Weber St.',
#   '7/27/1996',
#   '3',
#   '6',
#   'Buffalo Bills / 4th / 121st pick / 2018'],
#  ['25',
#   'Taiwan Jones',
#   '33',
#   'RB',
#   '17',
#   '0',
#   '195',
#   '6-0',
#   'East. Washington',
#   '7/26/1988',
#   '10',
#   '0',
#   'Oakland Raiders / 4th / 125th pick / 2011'],
#  ['54',
#   'A.J. Klein',
#   '30',
#   'ILB',
#   '15',
#   '4',
#   '240',
#   '6-1',
#   'Iowa St.',
#   '7/30/1991',
#   '8',
#   '4',
#   'Carolina Panthers / 5th / 148th pick / 2013'],
#  ['88',
#   'Dawson Knox',
#   '25',
#   'TE',
#   '15',
#   '14',
#   '254',
#   '6-4',
#   'Mississippi',
#   '11/14/1996',
#   '2',
#   '6',
#   'Buffalo Bills / 3rd / 96th pick / 2019'],
#  ['15',
#   'Jake Kumerow',
#   '29',
#   'WR',
#   '15',
#   '2',
#   '209',
#   '6-4',
#   'Wisconsin–Whitewater',
#   '2/17/1992',
#   '3',
#   '0',
#   ''],
#  ['47',
#   'Cameron Lewis',
#   '24',
#   'DB',
#   '7',
#   '1',
#   '185',
#   '5-9',
#   'Buffalo',
#   '4/13/1997',
#   '1',
#   '1',
#   ''],
#  ['98',
#   'Star Lotulelei',
#   '32',
#   'DT',
#   '11',
#   '8',
#   '315',
#   '6-2',
#   'Snow College (UT),Utah',
#   '12/20/1989',
#   '8',
#   '5',
#   'Carolina Panthers / 1st / 14th pick / 2013'],
#  ['44',
#   'Tyler Matakevich',
#   '29',
#   'ILB',
#   '17',
#   '0',
#   '235',
#   '6-1',
#   'Temple',
#   '12/22/1992',
#   '5',
#   '2',
#   'Pittsburgh Steelers / 7th / 246th pick / 2016'],
#  ['19',
#   'Isaiah McKenzie',
#   '26',
#   'WR',
#   '15',
#   '2',
#   '173',
#   '5-8',
#   'Georgia',
#   '4/9/1995',
#   '4',
#   '2',
#   'Denver Broncos / 5th / 172nd pick / 2017'],
#  ['58',
#   'Matt Milano',
#   '27',
#   'OLB',
#   '16',
#   '16',
#   '223',
#   '6-0',
#   'Boston Col.',
#   '7/28/1994',
#   '4',
#   '10',
#   'Buffalo Bills / 5th / 163rd pick / 2017'],
#  ['60',
#   'Mitch Morse',
#   '29',
#   'C',
#   '17',
#   '17',
#   '305',
#   '6-6',
#   'Missouri',
#   '4/21/1992',
#   '6',
#   '8',
#   'Kansas City Chiefs / 2nd / 49th pick / 2015'],
#  ['20',
#   'Zack Moss',
#   '24',
#   'RB',
#   '13',
#   '0',
#   '205',
#   '5-9',
#   'Utah',
#   '12/15/1997',
#   '1',
#   '4',
#   'Buffalo Bills / 3rd / 86th pick / 2020'],
#  ['33',
#   'Siran Neal',
#   '27',
#   'CB',
#   '17',
#   '0',
#   '206',
#   '6-0',
#   'Jacksonville St.',
#   '8/4/1994',
#   '3',
#   '1',
#   'Buffalo Bills / 5th / 154th pick / 2018'],
#  ['93',
#   'Efe Obada',
#   '29',
#   'LB',
#   '10',
#   '1',
#   '265',
#   '6-6',
#   'None',
#   '4/13/1992',
#   '3',
#   '2',
#   ''],
#  ['91',
#   'Ed Oliver',
#   '24',
#   'DL',
#   '17',
#   '17',
#   '287',
#   '6-1',
#   'Houston',
#   '12/12/1997',
#   '2',
#   '10',
#   'Buffalo Bills / 1st / 9th pick / 2019'],
#  ['99',
#   'Harrison Phillips',
#   '25',
#   'DT',
#   '14',
#   '8',
#   '307',
#   '6-3',
#   'Stanford',
#   '1/25/1996',
#   '3',
#   '6',
#   'Buffalo Bills / 3rd / 96th pick / 2018'],
#  ['21',
#   'Jordan Poyer',
#   '30',
#   'CB',
#   '16',
#   '16',
#   '191',
#   '6-0',
#   'Oregon St.',
#   '4/25/1991',
#   '8',
#   '13',
#   'Philadelphia Eagles / 7th / 218th pick / 2013'],
#  ['50',
#   'Gregory Rousseau',
#   '21',
#   'DE',
#   '17',
#   '17',
#   '266',
#   '6-6',
#   'Miami (FL)',
#   '4/5/2000',
#   'Rook',
#   '10',
#   'Buffalo Bills / 1st / 30th pick / 2021'],
#  ['1',
#   'Emmanuel Sanders',
#   '34',
#   'WR',
#   '14',
#   '13',
#   '180',
#   '5-11',
#   'SMU',
#   '3/17/1987',
#   '11',
#   '6',
#   'Pittsburgh Steelers / 3rd / 82nd pick / 2010'],
#  ['26',
#   'Devin Singletary',
#   '24',
#   'RB',
#   '17',
#   '16',
#   '203',
#   '5-7',
#   'Florida Atlantic',
#   '9/3/1997',
#   '2',
#   '8',
#   'Buffalo Bills / 3rd / 74th pick / 2019'],
#  ['59',
#   'Andre Smith',
#   '24',
#   'ILB',
#   '15',
#   '0',
#   '240',
#   '6-0',
#   'North Carolina',
#   '4/20/1997',
#   '3',
#   '2',
#   'Carolina Panthers / 7th / 234th pick / 2018'],
#  ['5',
#   'Marquez Stevenson',
#   '23',
#   'WR',
#   '5',
#   '0',
#   '190',
#   '6-0',
#   'Houston',
#   '3/26/1998',
#   'Rook',
#   '0',
#   'Buffalo Bills / 6th / 203rd pick / 2021'],
#  ['89',
#   'Tommy Sweeney',
#   '26',
#   'TE',
#   '13',
#   '3',
#   '251',
#   '6-5',
#   'Boston Col.',
#   '7/1/1995',
#   '2',
#   '0',
#   'Buffalo Bills / 7th / 228th pick / 2019'],
#  ['10',
#   'Mitchell Trubisky',
#   '27',
#   'QB',
#   '6',
#   '0',
#   '220',
#   '6-2',
#   'North Carolina',
#   '8/20/1994',
#   '4',
#   '0',
#   'Chicago Bears / 1st / 2nd pick / 2017'],
#  ['39',
#   'Levi Wallace',
#   '26',
#   'CB',
#   '17',
#   '17',
#   '179',
#   '6-0',
#   'Alabama',
#   '6/12/1995',
#   '3',
#   '7',
#   ''],
#  ['81',
#   'Kahale Warring',
#   '24',
#   'TE',
#   '1',
#   '0',
#   '252',
#   '6-5',
#   'San Diego St.',
#   '3/23/1997',
#   '1',
#   '0',
#   'Houston Texans / 3rd / 86th pick / 2019'],
#  ['7',
#   'Davis Webb',
#   '26',
#   'QB',
#   '1',
#   '0',
#   '225',
#   '6-5',
#   'California',
#   '1/22/1995',
#   '3',
#   '0',
#   'New York Giants / 3rd / 87th pick / 2017'],
#  ['27',
#   "Tre'Davious White",
#   '26',
#   'CB',
#   '11',
#   '11',
#   '192',
#   '5-11',
#   'LSU',
#   '1/16/1995',
#   '4',
#   '4',
#   'Buffalo Bills / 1st / 27th pick / 2017'],
#  ['75',
#   'Daryl Williams',
#   '29',
#   'OT',
#   '17',
#   '17',
#   '330',
#   '6-6',
#   'Oklahoma',
#   '8/31/1992',
#   '6',
#   '10',
#   'Carolina Panthers / 4th / 102nd pick / 2015'],
#  ['61',
#   'Justin Zimmer',
#   '29',
#   'DT',
#   '6',
#   '0',
#   '300',
#   '6-3',
#   'Ferris St.',
#   '10/23/1992',
#   '3',
#   '1',
#   ''],
#  ['',
#   'Team Total',
#   '26.5',
#   '',
#   '17',
#   '',
#   '244.9',
#   '6-2.0',
#   '',
#   '',
#   '3.6',
#   '',
#   '']]

# %%
tab_data[0]
# Out:
# ['No.',
#  'Player',
#  'Age',
#  'Pos',
#  'G',
#  'GS',
#  'Wt',
#  'Ht',
#  'College/Univ',
#  'BirthDate',
#  'Yrs',
#  'AV',
#  'Drafted (tm/rnd/yr)']

# %%
df = pd.DataFrame(tab_data[1:-1], columns = tab_data[0])

# %%
df = df.drop(30) #this row is a repeat of column names

# %%
df[['No.', 'Age', 'G', 'GS', 'Wt', 'AV']] = df[['No.', 'Age', 'G', 'GS', 'Wt', 'AV']].apply(pd.to_numeric)

# %%
df
# Out:
#     No.             Player  Age Pos   G  GS   Wt    Ht      College/Univ  \
# 0    97      Mario Addison   34  DE  17   0  260   6-3              Troy
# 1    17         Josh Allen   25  QB  17  17  237   6-5           Wyoming
# 2    51          Eli Ankou   27  DT   5   0  325   6-3              UCLA
# 3    96      Boogie Basham   24  DL   8   0  281   6-3       Wake Forest
# 4     2         Tyler Bass   24   K  17   0  183  5-10  Georgia Southern
# ..  ...                ...  ...  ..  ..  ..  ...   ...               ...
# 58   81     Kahale Warring   24  TE   1   0  252   6-5     San Diego St.
# 59    7         Davis Webb   26  QB   1   0  225   6-5        California
# 60   27  Tre'Davious White   26  CB  11  11  192  5-11               LSU
# 61   75     Daryl Williams   29  OT  17  17  330   6-6          Oklahoma
# 62   61      Justin Zimmer   29  DT   6   0  300   6-3        Ferris St.
#
#      BirthDate   Yrs  AV                          Drafted (tm/rnd/yr)
# 0     9/6/1987    10   2
# 1    5/21/1996     3  19        Buffalo Bills / 1st / 7th pick / 2018
# 2     6/8/1994     4   1
# 3   12/16/1997  Rook   1       Buffalo Bills / 2nd / 61st pick / 2021
# 4    2/14/1997     1   3      Buffalo Bills / 6th / 188th pick / 2020
# ..         ...   ...  ..                                          ...
# 58   3/23/1997     1   0      Houston Texans / 3rd / 86th pick / 2019
# 59   1/22/1995     3   0     New York Giants / 3rd / 87th pick / 2017
# 60   1/16/1995     4   4       Buffalo Bills / 1st / 27th pick / 2017
# 61   8/31/1992     6  10  Carolina Panthers / 4th / 102nd pick / 2015
# 62  10/23/1992     3   1
#
# [62 rows x 13 columns]

# %%
#do for each team

# %%
#scrape spotrac data

# %% [markdown]
# **Inspect dataset, prepare data appropriately**

# %% [markdown]
# Want to have dataframe that at least has player position({'str':float64}), salary(real()), value(av()), and yearly salary cap (real()) formatted properly

# %% [markdown]
# **Cluster salaries**

# %% [markdown]
# I think this is mostly done using an ai?

# %% [markdown]
# **Evaluate all players value compared to salary**
#
# value_per_dollar = av / salary

# %% [markdown]
# **Visualize and evaluate**
# analyze by clusters(look up how to cluster, pretty sure this is done with basic ai) (use mean. assumpt: In NFL, team control to block player movement prevents teams from paying above market rate, and that teams would do so to extract value. However, they can't so much of how it is distributed is (assumed)random. so each team is as likely to acquire players anywhere within that cluster of contracts.
#
# Use salary earned rather than cap figure to account for fact that that number fluctuates to accomodate teams to their cap needs, but doesn't reflect cost as effectively as salary)
#
# perc_cap = salary / salary_cap
#
# order clusters by value, how many of each can exist on a team, best distribution given need for at least 53(how many could become better understood)

# %% [markdown]
# **Ideas to explore**
#
# better ways to evaluate value than av
#
# how many players are needed on a roster, does that affect distribution?
#
# evaluate by positional value (did it have underlying effect in previous inquiry?)
#
# find teams historically that fit similar construction based on first inquiry, and compare their relative performance (AV, W/L, super bowl, etc)/
# find all possible clusters, look for their occurences in nfl teams and compare by their relative performance (AV, W/L, super bowl, etc)

# %% [markdown]
# **Sources**
#
# pfr scraping - https://stmorse.github.io/journal/pfr-scrape-python.html
#
# spotrac scraping - https://github.com/the-data-analyst/python_portfolio_web_scraper-spotrac/blob/master/webScraping_sample.py
